# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\ABC\Downloads\bitcoindata.csv")

# %%
print(df.head())
# Out:
#         Start         End      Open      High       Low     Close  \
# 0  2024-04-24  2024-04-25  66553.54  67070.40  63742.73  64291.07
# 1  2024-04-23  2024-04-24  66761.02  67174.02  65884.15  66386.61
# 2  2024-04-22  2024-04-23  64952.02  67180.03  64598.00  66818.89
# 3  2024-04-21  2024-04-22  64875.75  65638.74  64302.47  64896.87
# 4  2024-04-20  2024-04-21  63824.06  65351.33  63321.19  64857.99
#
#          Volume    Market Cap
# 0  1.384736e+11  1.294489e+12
# 1  1.408621e+11  1.308576e+12
# 2  1.400725e+11  1.299703e+12
# 3  1.326574e+11  1.278730e+12
# 4  1.537410e+11  1.263725e+12

# %%
print(df.dtypes)
# Out:
# Start          object
# End            object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
print(df.describe())
# Out:
#                Open          High           Low         Close        Volume  \
# count   5021.000000   5021.000000   5021.000000   5021.000000  5.021000e+03
# mean   11169.595248  11431.896431  10894.339275  11183.603552  2.034638e+10
# std    16440.239572  16829.731891  16025.693643  16459.827560  3.260079e+10
# min        0.057000      0.057000      0.057000      0.057000  0.000000e+00
# 25%      229.705000    232.705000    226.220000    229.689000  6.755427e+06
# 50%     2398.840000   2515.270000   2296.810000   2401.800000  9.920291e+08
# 75%    16537.454200  16785.892298  16065.167992  16549.983266  3.281635e+10
# max    72961.030000  73628.430000  71333.360000  73087.950000  2.121515e+11
#
#          Market Cap
# count  5.021000e+03
# mean   2.097941e+11
# std    3.149496e+11
# min    0.000000e+00
# 25%    3.275508e+09
# 50%    3.958854e+10
# 75%    3.091939e+11
# max    1.428493e+12

# %%
print(df.isnull().sum())
# Out:
# Start         0
# End           0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
print(df['Start'].describe())
# Out:
# count           5021
# unique          5021
# top       2024-04-24
# freq               1
# Name: Start, dtype: object

# %%
df['Start'].hist()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Start'], df['Close'], color='blue')
plt.title('Bitcoin Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Volume'], bins=50, color='green', alpha=0.7)
plt.title('Histogram of Bitcoin Daily Trading Volumes')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Close'], color='orange')
plt.title('Box Plot of Bitcoin Closing Prices')
plt.ylabel('Closing Price (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['High'], df['Low'], color='red', alpha=0.5)
plt.title('Scatter Plot of Bitcoin High Prices vs. Low Prices')
plt.xlabel('High Price (USD)')
plt.ylabel('Low Price (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Start'], df['Market Cap'], color='purple')
plt.title('Bitcoin Market Capitalization Over Time')
plt.xlabel('Date')
plt.ylabel('Market Cap (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Close'], shade=True, color='magenta')
plt.title('Density Plot of Bitcoin Closing Prices')
plt.xlabel('Closing Price (USD)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
df['Start'] = pd.to_datetime(df['Start'])

df['Year'] = df['Start'].dt.year

yearly_mean_close = df.groupby('Year')['Close'].mean()

plt.figure(figsize=(10, 6))
yearly_mean_close.plot(kind='bar', color='skyblue')
plt.title('Mean Bitcoin Closing Prices by Year')
plt.xlabel('Year')
plt.ylabel('Mean Closing Price (USD)')
plt.grid(True)
plt.show()
